# %%
import pandas as pd
import numpy as np
from typing import Dict, Any
from datetime import datetime
import numpy as np
from extract.extract_new_tokens import make_request
import logging
# Now you can use absolute imports
from utils.clean_numeric_columns import clean_numeric_columns
from utils.convert_boolean_columns import convert_boolean_columns
from utils.flatten_json import flatten_json
import json

# %%
import pandas as pd
from decimal import Decimal, InvalidOperation

def clean_numeric_columns(df, numeric_cols):
    """Converts numeric columns to Decimal for precision without worrying about trailing zeros."""
    for col in numeric_cols:
        if col in df.columns:
            # Convert to Decimal for high precision
            def convert_value(x):
                try:
                    if pd.isna(x) or str(x).strip() in ['', 'None', 'nan']:
                        return None  # Use None for missing values
                    return Decimal(str(x))  # Convert to Decimal
                except (InvalidOperation, TypeError, ValueError):
                    return None  # Handle invalid inputs
            
            df[col] = df[col].apply(convert_value)
    
    return df

# %%
raw_data = make_request()
with open("has_zero.json", "w", encoding="utf-8") as f:
    json.dump(raw_data, f, indent=4)
pd.set_option('future.no_silent_downcasting', True)

def transform_new_tokens(json_data: dict) -> pd.DataFrame:
    """Transforms and cleans GMGN JSON data into a properly typed DataFrame."""
    logging.info("Starting data transformation...")
    
    # Early return if no data
    if not json_data or not json_data.get('data', {}).get('pairs'):
        logging.warning("No data found in JSON input.")
        return pd.DataFrame()

    # Extract and flatten the raw data
    raw_data = json_data["data"]["pairs"]
    flat_records = [flatten_json(item) for item in raw_data]
    df = pd.DataFrame(flat_records)
    
    # Drop unnecessary columns
    cols_to_drop = [
        'id', 'pool_type', 'quote_address', 'base_token_info_launchpad_status',
        'base_token_info_buy_tax', 'base_token_info_sell_tax', 'base_token_info_is_honeypot',
        'base_token_info_renounced', 'base_token_info_dexscr_ad', 'base_token_info_dexscr_update_link',
        'base_token_info_is_open_source', 'base_token_info_lockInfo', 'base_token_info_progress'
    ]
    df.drop(columns=[col for col in cols_to_drop if col in df.columns], inplace=True)
    
    # Column combinations and filling missing values
    column_combinations = [
        ('pool_type_str', 'launchpad'),
        ('base_address', 'base_token_info_address'),
        ('base_token_info_burn_status', 'burn_status'),
        ('base_token_info_burn_ratio', 'burn_ratio'),
        ('base_token_info_liquidity', 'liquidity'),
        ('address', 'base_token_info_pool_id'),
        ('creation_timestamp', 'base_token_info_creation_timestamp')
    ]
    
    for new_col, old_col in column_combinations:
        if new_col in df.columns and old_col in df.columns:
            df[new_col] = df[new_col].fillna(df[old_col])
            df.drop(columns=[old_col], inplace=True)
        elif new_col not in df.columns and old_col in df.columns:
            df[new_col] = df[old_col]
            df.drop(columns=[old_col], inplace=True)
    
    # Column renaming
    rename_map = {
        'address': 'pair_address',
        'base_address': 'address',
        'pool_type_str': 'platform',
        'base_token_info_symbol': 'symbol',
        'base_token_info_name': 'name',
        'base_token_info_logo': 'logo',
        'base_token_info_total_supply': 'total_supply',
        'base_token_info_holder_count': 'holder_count',
        'base_token_info_sniper_count': 'sniper_count',
        'base_token_info_price_change_percent1m': 'price_change_1m',
        'base_token_info_price_change_percent5m': 'price_change_5m',
        'base_token_info_price_change_percent1h': 'price_change_1h',
        'base_token_info_price': 'price',
        'base_token_info_is_show_alert': 'has_alert',
        'base_token_info_hot_level': 'hot_level',
        'base_token_info_liquidity': 'liquidity',
        'base_token_info_top_10_holder_rate': 'top_10_holder_rate',
        'base_token_info_renounced_mint': 'renounced_mint',
        'base_token_info_renounced_freeze_account': 'renounced_freeze_account',
        'base_token_info_social_links_twitter_username': 'twitter_username',
        'base_token_info_social_links_website': 'website',
        'base_token_info_social_links_telegram': 'telegram',
        'base_token_info_rug_ratio': 'rug_ratio',
        'base_token_info_is_wash_trading': 'is_wash_trading',
        'base_token_info_creator_balance_rate': 'creator_balance_rate',
        'base_token_info_rat_trader_amount_rate': 'rat_trader_amount_rate',
        'base_token_info_creator_token_status': 'creator_token_status',
        'base_token_info_bluechip_owner_percentage': 'bluechip_owner_percentage',
        'base_token_info_smart_degen_count': 'smart_degen_count',
        'base_token_info_renowned_count': 'renowned_count',
        'base_token_info_volume': 'volume',
        'base_token_info_swaps': 'swaps',
        'base_token_info_buys': 'buys',
        'base_token_info_sells': 'sells',
        'base_token_info_burn_status': 'burn_status',
        'base_token_info_burn_ratio': 'burn_ratio',
        'base_token_info_dev_token_burn_amount': 'dev_token_burn_amount',
        'base_token_info_dev_token_burn_ratio': 'dev_token_burn_ratio',
        'base_token_info_cto_flag': 'cto_flag',
        'base_token_info_twitter_change_flag': 'twitter_change_flag',
        'base_token_info_market_cap': 'market_cap',
        'base_token_info_creator_close': 'creator_close',
        'base_token_info_biggest_pool_address': 'biggest_pool_address'
    }
    
    existing_rename_map = {k: v for k, v in rename_map.items() if k in df.columns}
    df.rename(columns=existing_rename_map, inplace=True)

    # Timestamp conversion
    timestamp_cols = ['open_timestamp', 'creation_timestamp']
    for col in timestamp_cols:
        if col in df.columns:
            # First try UNIX timestamp, then string format
            try:
                df[col] = pd.to_datetime(df[col], unit='s', errors='coerce')
            except:
                df[col] = pd.to_datetime(df[col], errors='coerce')
    
    # Clean numeric columns
    numeric_cols = [
        'price', 'liquidity', 'volume', 'market_cap', 'quote_reserve',
        'initial_liquidity', 'initial_quote_reserve', 'total_supply',
        'holder_count', 'sniper_count', 'hot_level', 'top_10_holder_rate',
        'rug_ratio', 'rat_trader_amount_rate', 'bluechip_owner_percentage',
        'smart_degen_count', 'renowned_count', 'swaps', 'buys', 'sells',
        'buy_tax', 'sell_tax', 'dev_token_burn_amount', 'dev_token_burn_ratio',
           'bot_degen_count', 'launchpad_status'
    ]
    df = clean_numeric_columns(df, numeric_cols)
    
    # Convert boolean columns
    bool_cols = [
        'has_alert', 'is_wash_trading', 
        'renounced_mint', 'renounced_freeze_account', 'creator_close', 'cto_flag','twitter_change_flag'
    ]
    bool_map = {
        'true': True, 'false': False,
        '1': True, '0': False,
        'yes': True, 'no': False,
        't': True, 'f': False
    }
    df = convert_boolean_columns(df, bool_cols, bool_map)
    
    # Ensure address is clean
    if 'address' in df.columns:
        df['address'] = df['address'].str.strip()
        df = df[df['address'].notna()]
    
    # Add status column with default
    df['status'] = 'alive'
    
    # Final cleanup - replace NaN/NaT with appropriate values
    df = df.replace({np.nan: None, pd.NaT: None})
    
    # Validate and handle missing values in required columns
    required_cols = ['address', 'status', 'symbol', 'platform']
    missing_cols = [col for col in required_cols if col not in df.columns]
    if missing_cols:
        raise ValueError(f"Missing required columns: {missing_cols}")
    
    for col in required_cols:
        if col in df.columns:
            if df[col].dtype == 'object':  # String/object columns
                df[col] = df[col].fillna("")
            elif df[col].dtype == 'bool':  # Boolean columns
                df[col] = df[col].fillna(False)
            else:  # Numeric columns
                df[col] = df[col].fillna(0)
    
    logging.info(f"Transformed DataFrame shape: {df.shape}")
    logging.info(f"Columns in transformed DataFrame: {list(df.columns)}")
    
    return df
df = transform_new_tokens(raw_data)
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)  # Show all rows

df
# Out:
# 2025-04-10 07:23:18,817 - DEBUG - GETCONF __owningcontrollerprocess (runtime: 0.0001)
# 2025-04-10 07:23:18,828 - INFO - Successfully renewed Tor circuit
# 2025-04-10 07:23:24,471 - INFO - Error while receiving a control message (SocketClosed): received exception "read of closed file"
# 2025-04-10 07:23:24,472 - INFO - Using Tor IP: 171.25.193.235
# 2025-04-10 07:23:24,609 - INFO - HTTP Status Code: 403
# 2025-04-10 07:23:24,609 - WARNING - Received 403 Forbidden
# 2025-04-10 07:23:24,610 - INFO - Waiting 10.8s before retry...
# 2025-04-10 07:23:35,450 - DEBUG - GETCONF __owningcontrollerprocess (runtime: 0.0002)
# 2025-04-10 07:23:35,456 - INFO - Successfully renewed Tor circuit
# 2025-04-10 07:23:40,915 - INFO - Error while receiving a control message (SocketClosed): received exception "read of closed file"
# 2025-04-10 07:23:40,916 - INFO - Using Tor IP: 192.42.116.186
# 2025-04-10 07:23:41,561 - INFO - HTTP Status Code: 200
# 2025-04-10 07:23:41,568 - INFO - Filtered 90 new tokens from 100 total tokens
# 2025-04-10 07:23:41,568 - INFO - Total tracked tokens: 2000
# 2025-04-10 07:23:41,569 - INFO - Found 90 new tokens (from 100 total)
# 2025-04-10 07:23:41,576 - INFO - Starting data transformation...
# 2025-04-10 07:23:41,594 - INFO - Transformed DataFrame shape: (90, 53)
# 2025-04-10 07:23:41,595 - INFO - Columns in transformed DataFrame: ['pair_address', 'address', 'creation_timestamp', 'quote_symbol', 'open_timestamp', 'quote_reserve', 'initial_liquidity', 'initial_quote_reserve', 'quote_reserve_usd', 'name', 'symbol', 'logo', 'total_supply', 'creator_close', 'creator_token_status', 'burn_ratio', 'burn_status', 'biggest_pool_address', 'has_alert', 'hot_level', 'renounced_mint', 'renounced_freeze_account', 'dev_token_burn_amount', 'dev_token_burn_ratio', 'cto_flag', 'twitter_change_flag', 'liquidity', 'rug_ratio', 'top_10_holder_rate', 'creator_balance_rate', 'price_change_1m', 'price_change_5m', 'price_change_1h', 'holder_count', 'sniper_count', 'smart_degen_count', 'renowned_count', 'rat_trader_amount_rate', 'bluechip_owner_percentage', 'market_cap', 'is_wash_trading', 'volume', 'swaps', 'buys', 'sells', 'creator', 'platform', 'price', 'bot_degen_count', 'twitter_username', 'website', 'telegram', 'status']
#                                     pair_address  \
# 0   DKjkaRoAfR4dQ6vDbSb8uZfM9Q4qiRwwqddGQTTLoBvy
# 1   FXSmUGzwUjhE33e6usuAb3Qz7W5R8YG3yspbmaawjDd7
# 80          SOL  2025-04-10 06:18:47         0.04321            3.5316
# 81          SOL  2025-04-10 06:18:45          0.2077             35.01
# 82          SOL  2025-04-10 06:18:25        0.001232            3.5313
# 83          SOL  2025-04-10 06:18:24          0.0182            3.5313
# 84          SOL  2025-04-10 06:18:22         0.03021            3.5319
# 85          SOL  2025-04-10 06:18:22        29.05282            3.5319
# 86          SOL  2025-04-10 06:18:14          0.9655            3.5304
# 87          SOL  2025-04-10 06:18:03         0.08014            3.5307
# 88          SOL  2025-04-10 06:18:00          0.0109            3.5298
# 89          SOL  2025-04-10 06:17:54        0.001232            3.5277
#
#    initial_quote_reserve quote_reserve_usd                              name  \
# 0                0.01512            1.7646                                 A
# 1                0.01512            1.7647                       ELON JOCKEY
# 2                0.01512            1.7647                     BlackAmerican
# 3                     15              None                  Found The Retard
# 4                0.01512              None                          PissCoin
# 5                0.01512              None   amazon_dot_com ELONS CHARACTER
# 6                0.01512              None               Dat My Best Friend
# 7                0.01512              None                           SPX6900
# 8                0.01512              None                  Non Playable Cat
# 9                0.01512              None               first piss in space
# 10               0.01512              None                               🌒👅🌒
# 11               0.01512              None       Stripping live at 100k mcap
# 12               0.01512              None                    Mugshot Barbie
# 13               0.01512              None                              TAFZ
# 14               0.01512              None    Starlink Airborne Latency Test
# 15               0.01512              None               Elon_Is_A_Pedophile
# 16               0.01512              None               First PEPE in Space
# 17             200000000              None                        GHIBLI CR7
# 18               0.01512              None                        CryptoPaws
# 19               0.01512              None               Black Kanye Culture
# 20               0.01512              None                  Non Playable Cat
# 21               0.01512              None             Betty White in space
# 22               0.01512              None                           Lottery
# 23               0.01512              None               First Tokenized Dog
# 24               0.01512              None               Black Kanye Culture
# 25               0.01512              None                         DoggyDeFi
# 26               0.01512              None                      Gooner Kanye
# 27               0.01512              None               First Shit In Space
# 28               0.01512              None               First Tokenized Dog
# 29               0.01512              None                             no id
# 30               0.01512              None                    It That Crawls
# 31               0.01512              None              Kanyes Kinky Kulture
# 32               0.01512              None            ELONS PET CHICKEN NAME
# 33                     5              None                           BullRun
# 34               0.01512              None    amazon_dot_com ELONS CHARACTER
# 35               0.01512              None               ELON CHICKEN JOCKEY
# 36               0.01512              None               Trump's Tariff Song
# 37               0.01512              None          Amazon_dot_com Elon name
# 38               0.01512              None                 Crypto KittyVerse
# 39               0.01512              None                               zzz
# 40               0.01512              None                   Bully Elon Core
# 41               0.01512              None                8 INCH FIGGA NIGGA
# 42               0.01512              None                    chicken jockey
# 43               0.01512              None                         Sky Puppy
# 44               0.01512              None               Black Kanye Culture
# 45               0.01512              None                          CyreneAI
# 46               0.01512              None      Amazon_dot_com elon new name
# 47               0.01512              None                       Trump Vs Xi
# 48               0.01512              None                           ai meme
# 49               0.01512              None                           ai meme
# 50               0.01512              None           Beijing Grace Ratecolor
# 51               0.01512              None    Starlink Airborne Latency Test
# 52               0.01512              None         Justice For Sara Millerey
# 53               0.01512              None                     AMAZN_DOT_COM
# 54               0.01512              None                       ELON JOCKEY
# 55               0.01512              None               ELON AMAZON DOT COM
# 56              50000000              None                        The Gooner
# 57              50000000              None                     Action Figure
# 58               0.01512              None                        TailsToken
# 59               0.01512              None                  ELON PET CHICKEN
# 60               0.01512              None                          aresdiee
# 61               0.01512              None                    solana in 1991
# 62               0.01512              None                      ELON CHICKEN
# 63               0.01512              None                    KEKIUS_GROKIUS
# 64               0.01512              None                  Make it all back
# 65               0.01512              None                           Starbie
# 66                     1              None                     OG Trump Coin
# 67               0.01512              None                           Meeting
# 68                     1              None                            gooner
# 69               0.01512              None                   AMAZON_DOT_COM_
# 70               0.01512              None             put the sunglasses on
# 71                    79              None                         Trump BTC
# 72               0.01512              None               Black Kanye Culture
# 73               0.01512              None                      la gou ceshi
# 74               0.01512              None    amazon_dot_com ELONS CHARACTER
# 75               0.01512              None                          KOLSTOOL
# 76               0.01512              None                    That Nigga Ken
# 77               0.01512              None                            TESTER
# 78               0.01512              None  Supporting My Fortnite Community
# 79               0.01512              None             ELON POE 2 NAME PROOF
# 80               0.01512              None                     Black Rock AI
# 81                  0.15              None                          CRYPTOAI
# 82               0.01512              None              Kanyes Kinky Kulture
# 83               0.01512              None                            WORLD3
# 84               0.01512              None                           Future
# 85               0.01512              None                     frank da frog
# 86               0.01512              None                   Yomamafatasfuck
# 87               0.01512              None               Black Kanye Culture
# 88               0.01512              None               Trump Eat SPAGHETTI
# 89               0.01512              None                             Canye
#
#         symbol                                               logo  \
# 0            A                                               None
# 1   ELONJOCKEY                                               None
# 2        BLACK                                               None
# 3          FTR  https://gmgn.ai/external-res/c5332b39219b198a8...
# 4     PissCoin  https://pump.mypinata.cloud/ipfs/QmaCtybVah3JR...
# 5          ADC  https://pump.mypinata.cloud/ipfs/QmWx7NfXLfRC2...
# 6           BF  https://gmgn.ai/external-res/5d328a83ed4e41eaa...
# 7          SPX  https://pump.mypinata.cloud/ipfs/Qmb6VkcaqGrjB...
# 8          NPC  https://pump.mypinata.cloud/ipfs/QmPYGimN6drU7...
# 9    SPACEPISS  https://gmgn.ai/external-res/b912d09227204223e...
# 10     Moondog  https://gmgn.ai/external-res/06b0a4ee9dc623958...
# 11     naughty  https://gmgn.ai/external-res/b7ca66dd527a3fa1d...
# 12     MUGSHOT  https://gmgn.ai/external-res/747dcbb944f6d3c0a...
# 13        TAFZ  https://pump.mypinata.cloud/ipfs/QmZTvH13Fxsej...
# 14        SALT  https://pump.mypinata.cloud/ipfs/QmVLs28CV5fhp...
# 15        EIAP  https://gmgn.ai/external-res/52bcf33576b599abb...
# 16       Spepe  https://pump.mypinata.cloud/ipfs/QmPzqYg8grYWQ...
# 17   GHIBLICR7  https://gmgn.ai/external-res/2141bb5739945a27b...
# 18         CPW  https://gmgn.ai/external-res/38eb34e64ff699707...
# 19         BKC  https://pump.mypinata.cloud/ipfs/QmUzqfmyoMRis...
# 20         NPC  https://pump.mypinata.cloud/ipfs/QmPYGimN6drU7...
# 21        BWIS  https://gmgn.ai/external-res/93e7a088412dcb97c...
# 22       Lotto  https://gmgn.ai/external-res/344869d6a720b5f2f...
# 23       BITTY  https://pump.mypinata.cloud/ipfs/QmapXMP7krbUZ...
# 24         BKC  https://pump.mypinata.cloud/ipfs/QmUzqfmyoMRis...
# 66      GOONER  https://gmgn.ai/external-res/6ea73a19513902123...
# 67     Meeting  https://pump.mypinata.cloud/ipfs/QmSmfuZXgMJe6...
# 68         sol  https://gmgn.ai/external-res/e0bffd60d42362a67...
# 69      AMAZON  https://pump.mypinata.cloud/ipfs/QmciyPV6tdmer...
# 70        ⌐■_■  https://pump.mypinata.cloud/ipfs/QmX8X4bWAswuv...
# 71   Trump BTC  https://gmgn.ai/external-res/456e401d56a89961a...
# 72         BKC  https://pump.mypinata.cloud/ipfs/QmaK2g11dyULZ...
# 73      LGTEST                                               None
# 74         ADC  https://pump.mypinata.cloud/ipfs/QmWx7NfXLfRC2...
# 75    KOLSTOOL  https://gmgn.ai/external-res/e92f21aaae67ab4c6...
# 76    NiggaKen  https://pump.mypinata.cloud/ipfs/QmX5XF45kExhM...
# 77        test  https://pump.mypinata.cloud/ipfs/QmUvMLXv4hPSV...
# 78       CRYIN  https://gmgn.ai/external-res/bcc02c3c72f9dfc32...
# 79   HC_KEKIUS  https://pump.mypinata.cloud/ipfs/QmYQ4uyfouYsG...
# 80         BRI  https://pump.mypinata.cloud/ipfs/Qmf3tDTCVj5wX...
# 81    CRYPTOAI  https://gmgn.ai/external-res/438338e0853024997...
# 82         KKK  https://pump.mypinata.cloud/ipfs/QmVsrH3o3WyXM...
# 83        WLD3  https://pump.mypinata.cloud/ipfs/QmUiPSs2yGfG1...
# 84     Future   https://pump.mypinata.cloud/ipfs/QmaXJuy65k47G...
# 85       frank  https://pump.mypinata.cloud/ipfs/QmUwvx7xXruKm...
# 86      YOMAMA  https://gmgn.ai/external-res/da8d597212aac1c07...
# 87         BKC  https://pump.mypinata.cloud/ipfs/QmUzqfmyoMRis...
# 88  Donaghetti  https://pump.mypinata.cloud/ipfs/QmUvSYkkDedBE...
# 89       CANYE  https://pump.mypinata.cloud/ipfs/QmVjJP8vnrAAw...
#
#    total_supply  creator_close      creator_token_status burn_ratio  \
# 0    1000000000          False              creator_hold     1.0000
# 1    1000000000          False              creator_hold     1.0000
# 2    1000000000          False              creator_hold     1.0000
# 3    1000000000          False     creator_add_liquidity
# 4    1000000000          False              creator_hold     1.0000
# 5    1000000000          False              creator_hold     1.0000
# 6    1000000000          False              creator_hold     1.0000
# 7    1000000000          False     creator_add_liquidity     1.0000
# 8    1000000000          False             creator_close     1.0000
# 9    1000000000          False             creator_close     1.0000
# 10   1000000000          False             creator_close     1.0000
# 11   1000000000          False              creator_hold     1.0000
# 12   1000000000          False              creator_hold     1.0000
# 13   1000000000          False             creator_close     1.0000
# 14   1000000000          False              creator_hold     1.0000
# 15   1000000000          False             creator_close     1.0000
# 16   1000000000          False              creator_sell     1.0000
# 17   1000000000          False              creator_hold
# 18   1000000000          False             creator_close     1.0000
# 19   1000000000          False              creator_hold     1.0000
# 20   1000000000          False             creator_close     1.0000
# 21   1000000000          False              creator_hold     1.0000
# 22   1000000000          False              creator_hold     1.0000
# 23   1000000000          False             creator_close     1.0000
# 24   1000000000          False             creator_close     1.0000
# 25   1000000000          False             creator_close     1.0000
# 26   1000000000          False             creator_close     1.0000
# 27   1000000000          False             creator_close     1.0000
# 28   1000000000          False             creator_close     1.0000
# 29   1000000000          False             creator_close     1.0000
# 30   1000000000          False             creator_close     1.0000
# 31   1000000000          False             creator_close     1.0000
# 32   1000000000          False             creator_close     1.0000
# 33  10000000000          False  creator_remove_liquidity
# 34   1000000000          False             creator_close     1.0000
# 35   1000000000          False             creator_close     1.0000
# 36   1000000000          False             creator_close     1.0000
# 37   1000000000          False             creator_close     1.0000
# 38   1000000000          False             creator_close     1.0000
# 39   1000000000          False             creator_close     1.0000
# 40   1000000000          False             creator_close     1.0000
# 41   1000000000          False             creator_close     1.0000
# 42   1000000000          False             creator_close     1.0000
# 43   1000000000          False             creator_close     1.0000
# 44   1000000000          False             creator_close     1.0000
# 45   1000000000          False              creator_hold     1.0000
# 46   1000000000          False             creator_close     1.0000
# 47   1000000000          False             creator_close     1.0000
# 48   1000000000          False             creator_close     1.0000
# 49   1000000000          False             creator_close     1.0000
# 50   1000000000          False             creator_close     1.0000
# 51   1000000000          False              creator_hold     1.0000
# 52   1000000000          False             creator_close     1.0000
# 53   1000000000          False             creator_close     1.0000
# 54   1000000000          False             creator_close     1.0000
# 55   1000000000          False             creator_close     1.0000
# 56   1000000000          False  creator_remove_liquidity
# 57   1000000000          False             creator_close
# 58   1000000000          False             creator_close     1.0000
# 59   1000000000          False             creator_close     1.0000
# 60   1000000000          False              creator_hold     1.0000
# 61   1000000000          False             creator_close     1.0000
# 62   1000000000          False             creator_close     1.0000
# 63   1000000000          False             creator_close     1.0000
# 64   1000000000          False             creator_close     1.0000
# 65   1000000000          False             creator_close     1.0000
# 66   1000000000          False     creator_add_liquidity     1.0000
# 67   1000000000          False             creator_close     1.0000
# 68   1000000000          False     creator_add_liquidity
# 69   1000000000          False             creator_close     1.0000
# 70   1000000000          False             creator_close     1.0000
# 71   4700000000          False     creator_add_liquidity
# 72   1000000000          False              creator_hold     1.0000
# 73   1000000000          False             creator_close     1.0000
# 74   1000000000          False             creator_close     1.0000
# 75   1000000000          False             creator_close     1.0000
# 76   1000000000          False              creator_hold     1.0000
# 77   1000000000          False             creator_close     1.0000
# 78   1000000000          False             creator_close     1.0000
# 79   1000000000          False             creator_close     1.0000
# 80   1000000000          False              creator_hold     1.0000
# 81   1000000000          False              creator_hold
# 82   1000000000          False             creator_close     1.0000
# 83   1000000000          False             creator_close     1.0000
# 84   1000000000          False              creator_hold     1.0000
# 85   1000000000          False              creator_hold     1.0000
# 86   1000000000          False             creator_close     1.0000
# 87   1000000000          False             creator_close     1.0000
# 88   1000000000          False             creator_close     1.0000
# 89   1000000000          False             creator_close     1.0000
#
#    burn_status                          biggest_pool_address  has_alert  \
# 0         burn  DKjkaRoAfR4dQ6vDbSb8uZfM9Q4qiRwwqddGQTTLoBvy      False
# 1         burn  FXSmUGzwUjhE33e6usuAb3Qz7W5R8YG3yspbmaawjDd7      False
# 2         burn  7EgoWR58ZxXNb3mHrXJY7rwUCRWZjVAAx5kkQuBGPUsd      False
# 3      unknown                                          None       True
# 4         burn                                          None       True
# 5         burn                                          None       True
# 6         burn                                          None       True
# 7         burn                                          None       True
# 8         burn                                          None       True
# 9         burn                                          None       True
# 10        burn                                          None       True
# 11        burn                                          None       True
# 12        burn                                          None       True
# 13        burn                                          None       True
# 14        burn                                          None       True
# 15        burn                                          None       True
# 16        burn                                          None       True
# 17     unknown                                          None      False
# 18        burn                                          None       True
# 19        burn                                          None      False
# 20        burn                                          None       True
# 21        burn                                          None       True
# 22        burn                                          None       True
# 23        burn                                          None      False
# 24        burn                                          None       True
# 25        burn                                          None       True
# 26        burn                                          None       True
# 27        burn                                          None       True
# 28        burn                                          None       True
# 29        burn                                          None       True
# 30        burn                                          None       True
# 31        burn                                          None       True
# 32        burn                                          None       True
# 33     unknown                                          None       True
# 34        burn                                          None       True
# 35        burn                                          None       True
# 36        burn                                          None       True
# 37        burn                                          None       True
# 38        burn                                          None       True
# 39        burn                                          None       True
# 40        burn                                          None       True
# 41        burn                                          None       True
# 42        burn                                          None       True
# 43        burn                                          None       True
# 44        burn                                          None       True
# 45        burn                                          None      False
# 46        burn                                          None       True
# 47        burn                                          None       True
# 48        burn                                          None       True
# 49        burn                                          None       True
# 50        burn                                          None       True
# 51        burn                                          None       True
# 52        burn                                          None       True
# 53        burn                                          None       True
# 54        burn                                          None       True
# 55        burn                                          None       True
# 56     unknown                                          None       True
# 57     unknown                                          None      False
# 58        burn                                          None       True
# 59        burn                                          None       True
# 60        burn                                          None       True
# 61        burn                                          None       True
# 62        burn                                          None       True
# 63        burn                                          None       True
# 64        burn                                          None       True
# 65        burn                                          None       True
# 66        burn                                          None      False
# 67        burn                                          None       True
# 68     unknown                                          None       True
# 69        burn                                          None       True
# 70        burn                                          None       True
# 71     unknown                                          None      False
# 72        burn                                          None      False
# 73        burn                                          None       True
# 74        burn                                          None      False
# 75        burn                                          None       True
# 76        burn                                          None       True
# 77        burn                                          None       True
# 78        burn                                          None       True
# 79        burn                                          None       True
# 80        burn                                          None       True
# 81        none                                          None       True
# 82        burn                                          None       True
# 83        burn                                          None       True
# 84        burn                                          None       True
# 85        burn                                          None      False
# 86        burn                                          None       True
# 87        burn                                          None       True
# 88        burn                                          None       True
# 89        burn                                          None       True
#
#    hot_level  renounced_mint  renounced_freeze_account dev_token_burn_amount  \
# 0          0            True                      True                  None
# 1          0            True                      True                  None
# 2          0            True                      True                  None
# 3          0            True                      True                  None
# 4          0            True                      True                  None
# 5          0            True                      True                  None
# 6          0            True                      True                  None
# 7          0            True                      True                  None
# 8          0            True                      True                  None
# ...
# 81   raydium     3.724E-8               1
# 82      pump  0.000003314               1
# 83      pump  0.000003276              10
# 84      pump  0.000003277               1
# 85      pump   0.00001124              38
# 86      pump   0.00000361              11
# 87      pump   0.00000328               6
# 88      pump  0.000003272               7
# 89      pump  0.000003269               6
#
#                                twitter_username  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4
# 50                          https://www.grace-chn.com
# 51
# 52
# 53                                               None
# 54                                               None
# 55                                               None
# 56
# 57                   https://www.actionfiguresol.xyz/
# 58                                               None
# 59                                               None
# 60  https://solscan.io/account/ARESgaTi8MtazdJs8bs...
# 61  https://www.reddit.com/r/solana/comments/qv253...
# 62                                               None
# 63
# 64                             https://miab-sol.site/
# 65                             https://pump.fun/board
# 66
# 67  https://x.com/BRICSinfo/status/191007112208069...
# 68                                               None
# 69
# 70  https://knowyourmeme.com/memes/puts-on-sunglas...
# 71                                               None
# 72  https://x.com/midasxsol/status/191020822622785...
# 73                                               None
# 74
# 75                                               None
# 76                                               None
# 77           https://x.com/i/broadcasts/1vAxRDpYmgDGl
# 78  https://x.com/AdinReports/status/1887605620775...
# 79
# 80                https://www.blackrock.com/corporate
# 81                                               None
# 82
# 83                            https://x.com/WORLD3_AI
# 84                                               None
# 85                           https://frankdafrog.xyz/
# 86                                               None
# 87  https://x.com/midasxsol/status/191020822622785...
# 88  https://x.com/Lastbern/status/1877951461188915...
# 89                                               None
#
#                                              telegram status
# 0                                                None  alive
# 1                                                None  alive
# 2                                                None  alive
# 3                                                None  alive
# 4                                                      alive
# 5                                                      alive
# 6                                                      alive
# 7                                                None  alive
# 8                                                None  alive
# 9                                                      alive
# 10                                                     alive
# 11                                                     alive
# 12                                               None  alive
# 13                                                     alive
# 14                                                     alive
# 15                                                     alive
# 16                        https://pumpchat.cc/solana/  alive
# 17                            https://t.me/ghibli_cr7  alive
# 18                                               None  alive
# 19                                                     alive
# 20                                               None  alive
# 21                                               None  alive
# 22                                               None  alive
# 23                                                     alive
# 24                                                     alive
# 25                                               None  alive
# 26                                                     alive
# 27                                                     alive
# 28                                               None  alive
# 29                                               None  alive
# 30                                                     alive
# 31                                                     alive
# 32                                                     alive
# 33                                               None  alive
# 34                                                     alive
# 35                                                     alive
# 36                                                     alive
# 37                                                     alive
# 38                                               None  alive
# 39                                               None  alive
# 40                                                     alive
# 41                                               None  alive
# 42                                                     alive
# 43                                               None  alive
# 44                                                     alive
# 45                              https://t.me/CyreneAI  alive
# 46                                                     alive
# 47                                               None  alive
# 48                                                     alive
# 49                                                     alive
# 50                          https://t.me/BeijingGrace  alive
# 51                                                     alive
# 52                                                     alive
# 53                                               None  alive
# 54                                               None  alive
# 55                                               None  alive
# 56                                                     alive
# 57                         https://t.me/ActionFigure3  alive
# 58                                               None  alive
# 59                                                     alive
# 60                                                     alive
# 61                                                     alive
# 62                                               None  alive
# 63                                                     alive
# 64                                                     alive
# 65                                                     alive
# 66                                                     alive
# 67  https://x.com/BRICSinfo/status/191007112208069...  alive
# 68                                               None  alive
# 69                                                     alive
# 70                                                     alive
# 71                                               None  alive
# 72                                                     alive
# 73                                               None  alive
# 74                                                     alive
# 75                                               None  alive
# 76                                               None  alive
# 77                                                     alive
# 78                                                     alive
# 79                                                     alive
# 80                                                     alive
# 81                                               None  alive
# 82                                                     alive
# 83                                                     alive
# 84                                               None  alive
# 85                           https://t.me/frankdafrog  alive
# 86                                               None  alive
# 87                                                     alive
# 88                                                     alive
# 89                                               None  alive
